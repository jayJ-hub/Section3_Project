# %% [markdown]
# <a href="https://colab.research.google.com/github/jayJ-hub/Section3_Project/blob/main/pullData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install spotipy

# %% [markdown]
# #Pull Data - Spotify

# %% [markdown]
# - reference : https://www.kaggle.com/code/pavansanagapati/spotify-music-api-data-extraction-part1

# %%
#authorization to access API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 

client_id='be705b4aa6a941fb97f1c3d61e4aa574'
client_secret='8cdcf90e096b454b995465e8dd9b22a2'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Extract album by artist
# - 이름 input 나중에 바꾸기!

# %%
def addArtistAlbum(artist_name):
  result = sp.search(artist_name)

  #extract artist's uri link
  artists_uris = result['tracks']['items'][0]['artists'][0]['uri']

  #extract artist's albums
  artist_albums = sp.artist_albums(artists_uris, album_type='album')

  #store in individual lists
  for i in range(len(artist_albums['items'])):
      artist_album_names.append(artist_albums['items'][i]['name'])
      artist_album_uris.append(artist_albums['items'][i]['uri'])

# %%
artists = ["아이유", "AJR", "Panic at the Disco!", "Why don't We", "청하", "Charlie Puth", "Ed Sheeran", "Lauv", "JVKE", "Selena gomez", "Ariana Grande", "Fall Out Boy", "윤하","JP Saxe", "Max"]

artist_album_names = []
artist_album_uris = []
for i in range(len(artists)):
  addArtistAlbum(artists[i])

print(artist_album_names)
len(artist_album_uris)
# Out:
# ["IU 5th Album 'LILAC'", 'Palette', 'Modern Times – Epilogue', 'Modern Times', 'Last Fantasy', 'Growing Up', 'OK ORCHESTRA', 'OK ORCHESTRA', 'OK Orchestra', 'OK ORCHESTRA', 'OK ORCHESTRA', 'Neotheater', 'Neotheater', 'Neotheater', 'Neotheater', 'Neotheater', 'Neotheater', 'The Click (Deluxe Edition)', 'The Click (Deluxe Edition)', 'The Click (Deluxe Edition)', 'The Click (Deluxe Edition)', 'The Click (Deluxe Edition)', 'The Click', 'The Click', 'The Click', 'The Click', 'Viva Las Vengeance', 'Pray for the Wicked', "All My Friends We're Glorious: Death of a Bachelor Tour Live", 'Death of a Bachelor', 'Too Weird to Live, Too Rare to Die!', 'Vices & Virtues', 'Vices & Virtues', 'Vices & Virtues (Deluxe Edition)', 'Live in Chicago', 'Pretty. Odd.', 'Pretty. Odd.', "A Fever You Can't Sweat Out", "A Fever You Can't Sweat Out", "A Fever You Can't Sweat Out", 'King Size Manger', 'Your Man (Deluxe Edition)', 'Country State Of Mind', 'I Serve A Savior', 'I Serve A Savior', 'Deep South', 'Deep South', 'Live Across America', 'Muve Sessions: Punching Bag', 'Punching Bag', 'Haywire', 'Haywire', 'Haywire (Deluxe Edition)', 'Haywire', 'Everything Is Fine', 'Your Man', 'Long Black Train', 'Long Black Train', 'Bare&Rare, Pt. 1', 'Bare&Rare Pt.1', 'Bare&Rare, Pt. 1', 'Querencia', 'Querencia', 'Voicenotes', 'Nine Track Mind (Deluxe Edition)', 'Nine Track Mind (Deluxe Edition)', 'Nine Track Mind', 'Nine Track Mind', 'Nine Track Mind (Special Edition)', 'Nine Track Mind', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '= (Tour Edition)', '2step (The Remixes)', '2step (The Remixes)', '=', 'No.6 Collaborations Project', 'No.6 Collaborations Project', '÷ (Deluxe)', 'x (Wembley Edition)', '5', 'All 4 Nothing', "~how i'm feeling~", "~how i'm feeling~", "~how i'm feeling~ (the extras)", 'I met you when I was 18. (the playlist)', 'I met you when I was 18. (the extras)', 'Rare (Deluxe)', 'Rare (Deluxe)', 'Rare', 'Rare', 'Revival', 'Revival (Deluxe)', 'Revival (Deluxe)', 'Revival (Deluxe)', 'Stars Dance (Deluxe Edition)', 'Stars Dance', 'Stars Dance (Bonus Track Version)', 'Stars Dance', 'Positions (Deluxe)', 'Positions (Deluxe)', 'Positions', 'Positions', 'k bye for now (swt live)', 'thank u, next', 'Sweetener', 'Sweetener', 'thank u, next', 'Christmas & Chill (Japan Version)', 'Dangerous Woman', 'Dangerous Woman', 'Dangerous Woman', 'Dangerous Woman (Edited)', 'Dangerous Woman', 'Dangerous Woman', 'Dangerous Woman', 'My Everything (Italian Edition)', 'The Remix', 'My Everything (Deluxe)', 'Believers Never Die (Volume Two)', 'Believers Never Die (Volume Two)', 'MANIA', 'MANIA', 'Make America Psycho Again', 'Make America Psycho Again', 'Make America Psycho Again', 'American Beauty/American Psycho', 'Save Rock And Roll', 'Save Rock And Roll', 'Save Rock And Roll', 'Live In Tokyo', 'Save Rock And Roll (Commentary)', 'Folie à Deux', '**** Live In Phoenix', 'Live In Phoenix', 'Live In Phoenix', 'Folie à Deux (UK Standard)', 'Folie à Deux', 'Folie à Deux', "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'", "YOUNHA 6th Album 'END THEORY'", 'RescuE', 'People', 'Supersonic', 'ひとつ空の下', 'Someday', '혜성', '혜성', '고백하기 좋은 날', '고백하기 좋은 날', 'Go! Younha', 'Dangerous Levels Of Introspection (Stripped)', 'Dangerous Levels of Introspection (Deluxe Edition)', 'Dangerous Levels of Introspection', 'Colour Vision (Deluxe)', 'Colour Vision', 'Neon From Now On', "Hell's Kitchen Angel (Japan Version)", "Hell's Kitchen Angel", "Hell's Kitchen Angel"]
# 169

# %% [markdown]
# Extract all songs from every album

# %%
def album_songs(uri):
    album = uri 
    spotify_albums[album] = {}
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] 
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    
    #pull data on album tracks
    tracks = sp.album_tracks(album) 
    for n in range(len(tracks['items'])): 
        spotify_albums[album]['album'].append(artist_album_names[album_count]) 
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in artist_album_uris: #each album
    album_songs(i)
    print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# IU 5th Album 'LILAC' album songs has been added to spotify_albums dictionary
# Palette album songs has been added to spotify_albums dictionary
# Modern Times – Epilogue album songs has been added to spotify_albums dictionary
# Modern Times album songs has been added to spotify_albums dictionary
# Last Fantasy album songs has been added to spotify_albums dictionary
# Growing Up album songs has been added to spotify_albums dictionary
# OK ORCHESTRA album songs has been added to spotify_albums dictionary
# OK ORCHESTRA album songs has been added to spotify_albums dictionary
# OK Orchestra album songs has been added to spotify_albums dictionary
# OK ORCHESTRA album songs has been added to spotify_albums dictionary
# OK ORCHESTRA album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# Neotheater album songs has been added to spotify_albums dictionary
# The Click (Deluxe Edition) album songs has been added to spotify_albums dictionary
# The Click (Deluxe Edition) album songs has been added to spotify_albums dictionary
# The Click (Deluxe Edition) album songs has been added to spotify_albums dictionary
# The Click (Deluxe Edition) album songs has been added to spotify_albums dictionary
# The Click (Deluxe Edition) album songs has been added to spotify_albums dictionary
# The Click album songs has been added to spotify_albums dictionary
# The Click album songs has been added to spotify_albums dictionary
# The Click album songs has been added to spotify_albums dictionary
# The Click album songs has been added to spotify_albums dictionary
# Viva Las Vengeance album songs has been added to spotify_albums dictionary
# Pray for the Wicked album songs has been added to spotify_albums dictionary
# All My Friends We're Glorious: Death of a Bachelor Tour Live album songs has been added to spotify_albums dictionary
# Death of a Bachelor album songs has been added to spotify_albums dictionary
# Too Weird to Live, Too Rare to Die! album songs has been added to spotify_albums dictionary
# Vices & Virtues album songs has been added to spotify_albums dictionary
# Vices & Virtues album songs has been added to spotify_albums dictionary
# Vices & Virtues (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Live in Chicago album songs has been added to spotify_albums dictionary
# Pretty. Odd. album songs has been added to spotify_albums dictionary
# Pretty. Odd. album songs has been added to spotify_albums dictionary
# A Fever You Can't Sweat Out album songs has been added to spotify_albums dictionary
# A Fever You Can't Sweat Out album songs has been added to spotify_albums dictionary
# A Fever You Can't Sweat Out album songs has been added to spotify_albums dictionary
# King Size Manger album songs has been added to spotify_albums dictionary
# Your Man (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Country State Of Mind album songs has been added to spotify_albums dictionary
# I Serve A Savior album songs has been added to spotify_albums dictionary
# I Serve A Savior album songs has been added to spotify_albums dictionary
# Deep South album songs has been added to spotify_albums dictionary
# Deep South album songs has been added to spotify_albums dictionary
# Live Across America album songs has been added to spotify_albums dictionary
# Muve Sessions: Punching Bag album songs has been added to spotify_albums dictionary
# Punching Bag album songs has been added to spotify_albums dictionary
# Haywire album songs has been added to spotify_albums dictionary
# Haywire album songs has been added to spotify_albums dictionary
# Haywire (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Haywire album songs has been added to spotify_albums dictionary
# Everything Is Fine album songs has been added to spotify_albums dictionary
# Your Man album songs has been added to spotify_albums dictionary
# Long Black Train album songs has been added to spotify_albums dictionary
# Long Black Train album songs has been added to spotify_albums dictionary
# Bare&Rare, Pt. 1 album songs has been added to spotify_albums dictionary
# Bare&Rare Pt.1 album songs has been added to spotify_albums dictionary
# Bare&Rare, Pt. 1 album songs has been added to spotify_albums dictionary
# Querencia album songs has been added to spotify_albums dictionary
# Querencia album songs has been added to spotify_albums dictionary
# Voicenotes album songs has been added to spotify_albums dictionary
# Nine Track Mind (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Nine Track Mind (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Nine Track Mind album songs has been added to spotify_albums dictionary
# Nine Track Mind album songs has been added to spotify_albums dictionary
# Nine Track Mind (Special Edition) album songs has been added to spotify_albums dictionary
# Nine Track Mind album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# = (Tour Edition) album songs has been added to spotify_albums dictionary
# 2step (The Remixes) album songs has been added to spotify_albums dictionary
# 2step (The Remixes) album songs has been added to spotify_albums dictionary
# = album songs has been added to spotify_albums dictionary
# No.6 Collaborations Project album songs has been added to spotify_albums dictionary
# No.6 Collaborations Project album songs has been added to spotify_albums dictionary
# ÷ (Deluxe) album songs has been added to spotify_albums dictionary
# x (Wembley Edition) album songs has been added to spotify_albums dictionary
# 5 album songs has been added to spotify_albums dictionary
# All 4 Nothing album songs has been added to spotify_albums dictionary
# ~how i'm feeling~ album songs has been added to spotify_albums dictionary
# ~how i'm feeling~ album songs has been added to spotify_albums dictionary
# ~how i'm feeling~ (the extras) album songs has been added to spotify_albums dictionary
# I met you when I was 18. (the playlist) album songs has been added to spotify_albums dictionary
# I met you when I was 18. (the extras) album songs has been added to spotify_albums dictionary
# Rare (Deluxe) album songs has been added to spotify_albums dictionary
# Rare (Deluxe) album songs has been added to spotify_albums dictionary
# Rare album songs has been added to spotify_albums dictionary
# Rare album songs has been added to spotify_albums dictionary
# Revival album songs has been added to spotify_albums dictionary
# Revival (Deluxe) album songs has been added to spotify_albums dictionary
# Revival (Deluxe) album songs has been added to spotify_albums dictionary
# Revival (Deluxe) album songs has been added to spotify_albums dictionary
# Stars Dance (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Stars Dance album songs has been added to spotify_albums dictionary
# Stars Dance (Bonus Track Version) album songs has been added to spotify_albums dictionary
# Stars Dance album songs has been added to spotify_albums dictionary
# Positions (Deluxe) album songs has been added to spotify_albums dictionary
# Positions (Deluxe) album songs has been added to spotify_albums dictionary
# Positions album songs has been added to spotify_albums dictionary
# Positions album songs has been added to spotify_albums dictionary
# k bye for now (swt live) album songs has been added to spotify_albums dictionary
# thank u, next album songs has been added to spotify_albums dictionary
# Sweetener album songs has been added to spotify_albums dictionary
# Sweetener album songs has been added to spotify_albums dictionary
# thank u, next album songs has been added to spotify_albums dictionary
# Christmas & Chill (Japan Version) album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# Dangerous Woman (Edited) album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# Dangerous Woman album songs has been added to spotify_albums dictionary
# My Everything (Italian Edition) album songs has been added to spotify_albums dictionary
# The Remix album songs has been added to spotify_albums dictionary
# My Everything (Deluxe) album songs has been added to spotify_albums dictionary
# Believers Never Die (Volume Two) album songs has been added to spotify_albums dictionary
# Believers Never Die (Volume Two) album songs has been added to spotify_albums dictionary
# MANIA album songs has been added to spotify_albums dictionary
# MANIA album songs has been added to spotify_albums dictionary
# Make America Psycho Again album songs has been added to spotify_albums dictionary
# Make America Psycho Again album songs has been added to spotify_albums dictionary
# Make America Psycho Again album songs has been added to spotify_albums dictionary
# American Beauty/American Psycho album songs has been added to spotify_albums dictionary
# Save Rock And Roll album songs has been added to spotify_albums dictionary
# Save Rock And Roll album songs has been added to spotify_albums dictionary
# Save Rock And Roll album songs has been added to spotify_albums dictionary
# Live In Tokyo album songs has been added to spotify_albums dictionary
# Save Rock And Roll (Commentary) album songs has been added to spotify_albums dictionary
# Folie à Deux album songs has been added to spotify_albums dictionary
# **** Live In Phoenix album songs has been added to spotify_albums dictionary
# Live In Phoenix album songs has been added to spotify_albums dictionary
# Live In Phoenix album songs has been added to spotify_albums dictionary
# Folie à Deux (UK Standard) album songs has been added to spotify_albums dictionary
# Folie à Deux album songs has been added to spotify_albums dictionary
# Folie à Deux album songs has been added to spotify_albums dictionary
# YOUNHA 6th Album Repackage 'END THEORY : Final Edition' album songs has been added to spotify_albums dictionary
# YOUNHA 6th Album 'END THEORY' album songs has been added to spotify_albums dictionary
# RescuE album songs has been added to spotify_albums dictionary
# People album songs has been added to spotify_albums dictionary
# Supersonic album songs has been added to spotify_albums dictionary
# ひとつ空の下 album songs has been added to spotify_albums dictionary
# Someday album songs has been added to spotify_albums dictionary
# 혜성 album songs has been added to spotify_albums dictionary
# 혜성 album songs has been added to spotify_albums dictionary
# 고백하기 좋은 날 album songs has been added to spotify_albums dictionary
# 고백하기 좋은 날 album songs has been added to spotify_albums dictionary
# Go! Younha album songs has been added to spotify_albums dictionary
# Dangerous Levels Of Introspection (Stripped) album songs has been added to spotify_albums dictionary
# Dangerous Levels of Introspection (Deluxe Edition) album songs has been added to spotify_albums dictionary
# Dangerous Levels of Introspection album songs has been added to spotify_albums dictionary
# Colour Vision (Deluxe) album songs has been added to spotify_albums dictionary
# Colour Vision album songs has been added to spotify_albums dictionary
# Neon From Now On album songs has been added to spotify_albums dictionary
# Hell's Kitchen Angel (Japan Version) album songs has been added to spotify_albums dictionary
# Hell's Kitchen Angel album songs has been added to spotify_albums dictionary
# Hell's Kitchen Angel album songs has been added to spotify_albums dictionary

# %% [markdown]
# Extract audio features for each song

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 20.417778968811035 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 26.931934595108032 seconds
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 35.477701902389526 seconds
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 51.8542754650116 seconds
# 25 playlists completed
# Loop #: 25
# Elapsed Time: 59.75333786010742 seconds
# 30 playlists completed
# Loop #: 30
# Elapsed Time: 71.65761470794678 seconds
# 35 playlists completed
# Loop #: 35
# Elapsed Time: 78.89685893058777 seconds
# 40 playlists completed
# Loop #: 40
# Elapsed Time: 87.18402743339539 seconds
# 45 playlists completed
# Loop #: 45
# Elapsed Time: 95.97499489784241 seconds
# 50 playlists completed
# Loop #: 50
# Elapsed Time: 103.9334442615509 seconds
# 55 playlists completed
# Loop #: 55
# Elapsed Time: 114.60874509811401 seconds
# 60 playlists completed
# Loop #: 60
# Elapsed Time: 122.29647946357727 seconds
# 65 playlists completed
# Loop #: 65
# Elapsed Time: 134.19491314888 seconds
# 70 playlists completed
# Loop #: 70
# Elapsed Time: 149.87678003311157 seconds
# 75 playlists completed
# Loop #: 75
# Elapsed Time: 173.67347717285156 seconds
# 80 playlists completed
# Loop #: 80
# Elapsed Time: 193.02938508987427 seconds
# 85 playlists completed
# Loop #: 85
# Elapsed Time: 210.64324617385864 seconds
# 90 playlists completed
# Loop #: 90
# Elapsed Time: 222.80385303497314 seconds
# 95 playlists completed
# Loop #: 95
# Elapsed Time: 242.85704970359802 seconds
# 100 playlists completed
# Loop #: 100
# Elapsed Time: 251.1668827533722 seconds
# 105 playlists completed
# Loop #: 105
# Elapsed Time: 264.157470703125 seconds
# 110 playlists completed
# Loop #: 110
# Elapsed Time: 282.6312460899353 seconds
# 115 playlists completed
# Loop #: 115
# Elapsed Time: 294.51460123062134 seconds
# 120 playlists completed
# Loop #: 120
# Elapsed Time: 303.39884066581726 seconds
# 125 playlists completed
# Loop #: 125
# Elapsed Time: 314.41560101509094 seconds
# 130 playlists completed
# Loop #: 130
# Elapsed Time: 331.9045236110687 seconds
# 135 playlists completed
# Loop #: 135
# Elapsed Time: 339.3948378562927 seconds
# 140 playlists completed
# Loop #: 140
# Elapsed Time: 352.02190709114075 seconds
# 145 playlists completed
# Loop #: 145
# Elapsed Time: 361.11201572418213 seconds
# 150 playlists completed
# Loop #: 150
# Elapsed Time: 373.17721819877625 seconds
# 155 playlists completed
# Loop #: 155
# Elapsed Time: 382.21565079689026 seconds
# 160 playlists completed
# Loop #: 160
# Elapsed Time: 396.24866008758545 seconds
# 165 playlists completed
# Loop #: 165
# Elapsed Time: 412.29219126701355 seconds

# %% [markdown]
# Add to DataFrame

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 2471

# %%
import pandas as pd
dataframe = pd.DataFrame.from_dict(dic_df)
dataframe
# Out:
#                      album  track_number                      id  \
# 0     IU 5th Album 'LILAC'             1  5xrtzzzikpG3BLbo4q1Yul
# 1     IU 5th Album 'LILAC'             2  2j0MsDAMJ2ahsxP3z86ChI
# 2     IU 5th Album 'LILAC'             3  7CZRguMolNqIobnXxpV735
# 3     IU 5th Album 'LILAC'             4  2M7a2Us8CEU1HZHj70byGX
# 4     IU 5th Album 'LILAC'             5  5nCwjUUsmBuNZKn9Xu10Os
# ...                    ...           ...                     ...
# 2466  Hell's Kitchen Angel             6  1Gewzuos0KL1dmgA4XPygF
# 2467  Hell's Kitchen Angel             7  5TeK4KDtsCHhnur4JNT1IN
# 2468  Hell's Kitchen Angel             8  5h8H1qDJhtr3scoufnDl4b
# 2469  Hell's Kitchen Angel             9  4aJgVVpcUos92SAESRL2Si
# 2470  Hell's Kitchen Angel            10  41T2wyrjQrBVCw2miqWIu0
#
#                              name                                   uri  \
# 0                           LILAC  spotify:track:5xrtzzzikpG3BLbo4q1Yul
# 1                             Flu  spotify:track:2j0MsDAMJ2ahsxP3z86ChI
# 2                            Coin  spotify:track:7CZRguMolNqIobnXxpV735
# 3                   Hi spring Bye  spotify:track:2M7a2Us8CEU1HZHj70byGX
# 4                       Celebrity  spotify:track:5nCwjUUsmBuNZKn9Xu10Os
# ...                           ...                                   ...
# 2466  10 Victoria's Secret Models  spotify:track:1Gewzuos0KL1dmgA4XPygF
# 2467                         Home  spotify:track:5TeK4KDtsCHhnur4JNT1IN
# 2468       Mug Shot (feat. Sirah)  spotify:track:5h8H1qDJhtr3scoufnDl4b
# 2469               Basement Party  spotify:track:4aJgVVpcUos92SAESRL2Si
# 2470                  Lost My Way  spotify:track:41T2wyrjQrBVCw2miqWIu0
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0          0.08950         0.738   0.890          0.000002    0.2130
# 1          0.09810         0.842   0.647          0.000000    0.1440
# 2          0.00849         0.725   0.879          0.000001    0.3160
# 3          0.77100         0.501   0.510          0.000003    0.0756
# 4          0.19100         0.730   0.784          0.000000    0.0956
# ...            ...           ...     ...               ...       ...
# 2466       0.01070         0.681   0.629          0.000000    0.0843
# 2467       0.02020         0.612   0.501          0.000000    0.0458
# 2468       0.01870         0.719   0.866          0.000000    0.3620
# 2469       0.05740         0.773   0.954          0.000000    0.0805
# 2470       0.38000         0.702   0.507          0.000003    0.1950
#
#       loudness  speechiness    tempo  valence  popularity
# 0       -2.275       0.0748  114.942    0.750          72
# 1       -4.753       0.1150   92.025    0.578          53
# 2       -3.351       0.1010  118.092    0.710          55
# 3       -5.996       0.0268   91.908    0.189          50
# 4       -2.620       0.0691   99.995    0.673          66
# ...        ...          ...      ...      ...         ...
# 2466    -6.167       0.0311  142.018    0.358          34
# 2467    -6.764       0.0433  143.839    0.490          27
# 2468    -5.574       0.1630  132.924    0.698          26
# 2469    -3.599       0.1130  112.031    0.686          31
# 2470    -8.194       0.0751  101.105    0.383          23
#
# [2471 rows x 15 columns]

# %%
print(len(dataframe))
final_df = dataframe.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 2471
# 1146

# %%
final_df
# Out:
#                      album  track_number                      id  \
# 0     IU 5th Album 'LILAC'             1  5xrtzzzikpG3BLbo4q1Yul
# 1     IU 5th Album 'LILAC'             2  2j0MsDAMJ2ahsxP3z86ChI
# 2     IU 5th Album 'LILAC'             3  7CZRguMolNqIobnXxpV735
# 3     IU 5th Album 'LILAC'             4  2M7a2Us8CEU1HZHj70byGX
# 4     IU 5th Album 'LILAC'             5  5nCwjUUsmBuNZKn9Xu10Os
# ...                    ...           ...                     ...
# 2457  Hell's Kitchen Angel             7  747JUFQOb9JL88fCbiiFY6
# 2458  Hell's Kitchen Angel             8  7roCTVRPs3VJfvq2tbsdWv
# 2460  Hell's Kitchen Angel            10  7gFiscQgYvhfeKvSh7SyDS
# 2465  Hell's Kitchen Angel             5  1sYSP7gKa5kdKIfhANfori
# 2469  Hell's Kitchen Angel             9  4aJgVVpcUos92SAESRL2Si
#
#                         name                                   uri  \
# 0                      LILAC  spotify:track:5xrtzzzikpG3BLbo4q1Yul
# 1                        Flu  spotify:track:2j0MsDAMJ2ahsxP3z86ChI
# 2                       Coin  spotify:track:7CZRguMolNqIobnXxpV735
# 3              Hi spring Bye  spotify:track:2M7a2Us8CEU1HZHj70byGX
# 4                  Celebrity  spotify:track:5nCwjUUsmBuNZKn9Xu10Os
# ...                      ...                                   ...
# 2457                    Home  spotify:track:747JUFQOb9JL88fCbiiFY6
# 2458  Mug Shot (feat. Sirah)  spotify:track:7roCTVRPs3VJfvq2tbsdWv
# 2460             Lost My Way  spotify:track:7gFiscQgYvhfeKvSh7SyDS
# 2465         Lights Down Low  spotify:track:1sYSP7gKa5kdKIfhANfori
# 2469          Basement Party  spotify:track:4aJgVVpcUos92SAESRL2Si
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0          0.08950         0.738   0.890          0.000002    0.2130
# 1          0.09810         0.842   0.647          0.000000    0.1440
# 2          0.00849         0.725   0.879          0.000001    0.3160
# 3          0.77100         0.501   0.510          0.000003    0.0756
# 4          0.19100         0.730   0.784          0.000000    0.0956
# ...            ...           ...     ...               ...       ...
# 2457       0.02020         0.612   0.501          0.000000    0.0458
# 2458       0.01870         0.719   0.866          0.000000    0.3620
# 2460       0.38000         0.702   0.507          0.000003    0.1950
# 2465       0.06320         0.623   0.493          0.000000    0.1040
# 2469       0.05740         0.773   0.954          0.000000    0.0805
#
#       loudness  speechiness    tempo  valence  popularity
# 0       -2.275       0.0748  114.942    0.750          72
# 1       -4.753       0.1150   92.025    0.578          53
# 2       -3.351       0.1010  118.092    0.710          55
# 3       -5.996       0.0268   91.908    0.189          50
# 4       -2.620       0.0691   99.995    0.673          66
# ...        ...          ...      ...      ...         ...
# 2457    -6.764       0.0433  143.839    0.490          30
# 2458    -5.574       0.1630  132.924    0.698          27
# 2460    -8.194       0.0751  101.105    0.383          24
# 2465    -7.727       0.0338   81.019    0.594          64
# 2469    -3.599       0.1130  112.031    0.686          31
#
# [1146 rows x 15 columns]

# %%
# final_df.to_csv("spotify_music.csv")
